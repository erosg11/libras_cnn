# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('raw_x_UFPR.npy')
data.shape
# Out:
# (1220, 282, 376, 1)

# %%
plt.imshow(data[5,:,:,0])

# %%
data2 = np.load('raw_x_UFMA.npy')

# %%
plt.imshow(data2[0,:,:,0])

# %%
data2.shape
# Out:
# (12200, 185, 180, 1)

# %%
data2.dtype
# Out:
# dtype('uint8')

# %%
data3 = np.load('asda/raw_x_UFPR2.npy')

# %%
plt.imshow(data3[11,:,:,0])

# %%
np.load('raw_x_UFPR.npy')[::2,...].shape
# Out:
# (610, 282, 376, 1)

# %%
np.load('raw_y_UFPR.npy')[::2,...].shape
# Out:
# (610,)

# %%
ys_ufpr = np.load('raw_y_UFPR.npy')

# %%
any(ys_ufpr[::2, ...] != ys_ufpr[1::2, ...])
# Out:
# False
